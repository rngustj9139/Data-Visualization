# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax = fig.add_axes([0, 0, 1, 1]) # 첫번째랑 두번째 인자는 ax의 맨 left와 맨 bottom을 의미 세번째는 width, 네번째는 height를 의미

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # 첫번째랑 두번째 인자는 ax의 맨 left와 맨 bottom을 의미 세번째는 width, 네번째는 height를 의미

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_axes([0.1, 0.1, 0.5, 0.5]) 
ax2 = fig.add_axes([0.7, 0.1, 0.2, 0.5]) 
ax3 = fig.add_axes([0.1, 0.7, 0.8, 0.2])

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_axes([0.1, 0.1, 0.6, 0.6])
ax2 = fig.add_axes([0.75, 0.1, 0.2, 0.6])
ax3 = fig.add_axes([0.1, 0.75, 0.6, 0.2])

# %%
fig = plt.figure(figsize=(7, 7), facecolor='linen')

ax1 = fig.add_subplot(1, 1, 1)
ax2 = fig.add_axes([0.4, 0.4, 0.45, 0.45])
